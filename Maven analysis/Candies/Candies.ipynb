# %% [markdown]
# 1. How do you read the candy dataset into a pandas DataFrame?

# %%
import pandas as pd
df=pd.read_csv("/workspace/Pyspark_projects/Maven analysis/candy-data.csv")
df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %% [markdown]
# 2. How do you display the first 5 rows of the DataFrame?

# %%
df.head(5)
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %% [markdown]
# 3. How do you get the column names of the DataFrame?

# %%
df.columns
# Out:
# Index(['competitorname', 'chocolate', 'fruity', 'caramel', 'peanutyalmondy',
#        'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent',
#        'pricepercent', 'winpercent'],
#       dtype='object')

# %% [markdown]
# 4.How do you filter the DataFrame to show only candies that contain chocolate?

# %%
filter_cho=df[df["chocolate"]==1]
filter_cho
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                     100 Grand          1       0        1               0
# 1                  3 Musketeers          1       0        0               0
# 5                    Almond Joy          1       0        0               1
# 6                     Baby Ruth          1       0        1               1
# 10              Charleston Chew          1       0        0               0
# 22             Hershey's Kisses          1       0        0               0
# 23            Hershey's Krackel          1       0        0               0
# 24     Hershey's Milk Chocolate          1       0        0               0
# 25       Hershey's Special Dark          1       0        0               0
# 27                 Junior Mints          1       0        0               0
# 28                      Kit Kat          1       0        0               0
# ...

# %% [markdown]
# 5.How do you add a new column to the DataFrame indicating whether the candy is both fruity and contains caramel?

# %%
df["fruit_carmel"]=((df["fruity"]==1) & (df["caramel"]==1)).astype("int")
df[df["fruit_carmel"]==1]
# Out:
#        competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 9  Caramel Apple Pops          0       1        1               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 9                 0     0    0         0         0.604         0.325
#
#    winpercent  fruit_carmel
# 9   34.517681             1

# %% [markdown]
# 6.How do you group the DataFrame by the ‘chocolate’ column and calculate the mean win percentage for each group?

# %%
f=df.groupby("chocolate")["winpercent"].mean()
f
# Out:
# chocolate
# 0    42.142257
# 1    60.921529
# Name: winpercent, dtype: float64

# %%
df.isna().sum()
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# fruit_carmel        0
# dtype: int64

# %% [markdown]
# 7.How do you sort the DataFrame by ‘winpercent’ and ‘pricepercent’ in descending order?

# %%
df.sort_values(["winpercent","pricepercent"],ascending=False).head(5)
# Out:
#                competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 52  Reese's Peanut Butter cup          1       0        0               1
# 51         Reese's Miniatures          1       0        0               1
# 79                       Twix          1       0        1               0
# 28                    Kit Kat          1       0        0               0
# 64                   Snickers          1       0        1               1
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 52       0                 0     0    0         0         0.720         0.651
# 51       0                 0     0    0         0         0.034         0.279
# 79       0                 1     0    1         0         0.546         0.906
# 28       0                 1     0    1         0         0.313         0.511
# 64       1                 0     0    1         0         0.546         0.651
#
#     winpercent  fruit_carmel
# ...

# %% [markdown]
# 8.How do you apply a custom function to create a new column that categorizes candies into ‘High Sugar’ or ‘Low Sugar’ based on the ‘sugarpercent’?

# %%
def catgeory(sugar):
    if sugar>0.5:
        return "High_sugar"
    else :
        return "Low_sugar"
df["value"]= df["sugarpercent"].apply(catgeory)
df[["competitorname","value","sugarpercent"]].head(10)
# Out:
#        competitorname       value  sugarpercent
# 0           100 Grand  High_sugar         0.732
# 1        3 Musketeers  High_sugar         0.604
# 2            One dime   Low_sugar         0.011
# 3         One quarter   Low_sugar         0.011
# 4           Air Heads  High_sugar         0.906
# 5          Almond Joy   Low_sugar         0.465
# 6           Baby Ruth  High_sugar         0.604
# 7  Boston Baked Beans   Low_sugar         0.313
# 8          Candy Corn  High_sugar         0.906
# 9  Caramel Apple Pops  High_sugar         0.604

# %% [markdown]
# 9.How do you create a new DataFrame that contains only the rows where ‘winpercent’ is above 50%?

# %%
win_50 = df[df["winpercent"]>=50]
win_50.head(10)
# Out:
#               competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                  100 Grand          1       0        1               0
# 1               3 Musketeers          1       0        0               0
# 4                  Air Heads          0       1        0               0
# 5                 Almond Joy          1       0        0               1
# 6                  Baby Ruth          1       0        1               1
# 18         Haribo Gold Bears          0       1        0               0
# 20         Haribo Sour Bears          0       1        0               0
# 22          Hershey's Kisses          1       0        0               0
# 23         Hershey's Krackel          1       0        0               0
# 24  Hershey's Milk Chocolate          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0        0                 1     0    1         0         0.732         0.860
# ...

# %% [markdown]
# 10.How do you use the map function to replace values in the ‘chocolate’ column with ‘Yes’ or ‘No’?

# %%
mappings= {1:"Yes",0:"No"}
newcho=df
newcho["necholcate"]=df["chocolate"].map(mappings)
newcho.head(10)
# Out:
#        competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0           100 Grand          1       0        1               0       0
# 1        3 Musketeers          1       0        0               0       1
# 2            One dime          0       0        0               0       0
# 3         One quarter          0       0        0               0       0
# 4           Air Heads          0       1        0               0       0
# 5          Almond Joy          1       0        0               1       0
# 6           Baby Ruth          1       0        1               1       1
# 7  Boston Baked Beans          0       0        0               1       0
# 8          Candy Corn          0       0        0               0       0
# 9  Caramel Apple Pops          0       1        1               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# ...

# %%
mappings= {1:"Yes",0:"No"}
df1=df
df1["1chocolate"]=df["chocolate"].replace({1:"Yes",0:"NO"})
df1
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %% [markdown]
# 11.How do you use the query function to filter the DataFrame for candies that are either fruity or contain caramel, but not both?

# %%
#df["carme_cho"]=(df["caramel"]==1)&(df["chocolate"]=="Yes") 
df["frt_car"]=(df["fruity"]==0)|(df["caramel"]==1)
df[df["frt_car"]==True].head(5)
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 5     Almond Joy          1       0        0               1       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 5                 0     0    1         0         0.465         0.767
#
#    winpercent  fruit_carmel       value necholcate 1chocolate  frt_car
# ...

# %% [markdown]
# 12.How do you use the rank function to rank candies based on their ‘winpercent’?

# %%
df["rank"]=df["winpercent"].rank()
df.sort_values("rank",ascending=False)
# Out:
#                competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 52  Reese's Peanut Butter cup          1       0        0               1
# 51         Reese's Miniatures          1       0        0               1
# 79                       Twix          1       0        1               0
# 28                    Kit Kat          1       0        0               0
# 64                   Snickers          1       0        1               1
# ..                        ...        ...     ...      ...             ...
# 26                 Jawbusters          0       1        0               0
# 72               Super Bubble          0       1        0               0
# 12                   Chiclets          0       1        0               0
# 7          Boston Baked Beans          0       0        0               1
# 44                  Nik L Nip          0       1        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# ...

# %% [markdown]
# 13. How do you use the to_csv function to write a DataFrame to a CSV file?
# df

# %%
df.to_csv("ouput1.csv",header=True,index=False,mode="w")
