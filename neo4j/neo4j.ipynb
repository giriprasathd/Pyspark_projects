# %%
pip install pyspark
# Out:
# ...
#   Using cached pyspark-3.5.3-py2.py3-none-any.whl
# ...
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv("/workspace/Pyspark_projects/neo4j/Kollywood Movie Dataset.csv")
df.head()
# Out:
#    Release Year             Title Language          Director  \
# 0          2011           Venghai    Tamil              Hari
# 1          2011  Deiva Thirumagal    Tamil       A. L. Vijay
# 2          2011          Kanchana    Tamil  Raghava Lawrence
# 3          2011         Karungali    Tamil        Kalanjiyam
# 4          2011            Veppam    Tamil   Anjana Ali Khan
#
#                                                 Cast          Genre  \
# 0                Dhanush, Tamannaah Bhatia, Rajkiran          drama
# 1      Vikram, Anushka Shetty, Amala Paul, Baby Sara          drama
# 2      Raghava Lawrence, R. Sarathkumar, Lakshmi Rai  comedy horror
# 3  Kalanjiyam, Anjali, Srinivas, Sunitha Varma, A...          drama
# 4   Karthik Kumar, Nani, Nithya Menen, Bindu Madhavi          drama
#
#                                                 Plot  Rating
# 0  Veera Pandi (Raj Kiran) is a powerful and rich...     4.7
# 1  Krishna (Vikram) is intellectually disabled an...     8.1
# ...

# %%
df["actors"]=df["Cast"].str.split(",")
df
# Out:
#      Release Year                Title Language                  Director  \
# 0            2011              Venghai    Tamil                      Hari
# 1            2011     Deiva Thirumagal    Tamil               A. L. Vijay
# 2            2011             Kanchana    Tamil          Raghava Lawrence
# 3            2011            Karungali    Tamil                Kalanjiyam
# 4            2011               Veppam    Tamil           Anjana Ali Khan
# ..            ...                  ...      ...                       ...
# 411          2017               Sathya    Tamil    Pradeep Krishnamoorthy
# 412          2017             Maayavan    Tamil               C. V. Kumar
# 413          2017                Aruvi    Tamil  Arun Prabu Purushothaman
# 414          2017  Chennai 2 Singapore    Tamil               Abbas Akbar
# 415          2017          Velaikkaran    Tamil                Mohan Raja
#
#                                                   Cast            Genre  \
# ...

# %%
df.drop(axis=0,columns="Plot")
# Out:
#      Release Year                Title Language                  Director  \
# 0            2011              Venghai    Tamil                      Hari
# 1            2011     Deiva Thirumagal    Tamil               A. L. Vijay
# 2            2011             Kanchana    Tamil          Raghava Lawrence
# 3            2011            Karungali    Tamil                Kalanjiyam
# 4            2011               Veppam    Tamil           Anjana Ali Khan
# ..            ...                  ...      ...                       ...
# 411          2017               Sathya    Tamil    Pradeep Krishnamoorthy
# 412          2017             Maayavan    Tamil               C. V. Kumar
# 413          2017                Aruvi    Tamil  Arun Prabu Purushothaman
# 414          2017  Chennai 2 Singapore    Tamil               Abbas Akbar
# 415          2017          Velaikkaran    Tamil                Mohan Raja
#
#                                                   Cast            Genre  \
# ...

# %%
df["Genre"].str.split(" ")
df
# Out:
#      Release Year                Title Language                  Director  \
# 0            2011              Venghai    Tamil                      Hari
# 1            2011     Deiva Thirumagal    Tamil               A. L. Vijay
# 2            2011             Kanchana    Tamil          Raghava Lawrence
# 3            2011            Karungali    Tamil                Kalanjiyam
# 4            2011               Veppam    Tamil           Anjana Ali Khan
# ..            ...                  ...      ...                       ...
# 411          2017               Sathya    Tamil    Pradeep Krishnamoorthy
# 412          2017             Maayavan    Tamil               C. V. Kumar
# 413          2017                Aruvi    Tamil  Arun Prabu Purushothaman
# 414          2017  Chennai 2 Singapore    Tamil               Abbas Akbar
# 415          2017          Velaikkaran    Tamil                Mohan Raja
#
#                                                   Cast            Genre  \
# ...

# %%
from pyspark.sql import SparkSession
spark =SparkSession.builder.appName("Neo4j").getOrCreate()
spark
# Out:
# Picked up JAVA_TOOL_OPTIONS: -XX:+UseContainerSupport -XX:ActiveProcessorCount=1
# Picked up JAVA_TOOL_OPTIONS: -XX:+UseContainerSupport -XX:ActiveProcessorCount=1
# 24/10/09 09:51:15 WARN Utils: Your hostname, giriprasath-pysparkproj-j72g1dznogr resolves to a loopback address: 127.0.0.1; using 10.0.5.2 instead (on interface eth0)
# 24/10/09 09:51:15 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/09 09:51:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.5.2:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
# ...

# %%
ds=spark.read.csv("/workspace/Pyspark_projects/neo4j/Kollywood Movie Dataset.csv",header=True)
